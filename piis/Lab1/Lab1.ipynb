# %% [markdown]
# # Лабораторная работа №1 "Многоклассовая классификация цветов"
# ### Выполнила студентка группы БВТ2101 Пьянова Анна Олеговна

# %% [markdown]
# ### Цель работы:
# Реализовать классификацию сортов растения ирис (Iris Setosa - 0, Iris Versicolour - 1, Iris Virginica - 2) по четырем признакам: размерам пестиков и тычинок его цветков.
# ### Задачи:
# - Ознакомиться с задачей классификации
# - Загрузить данные
# - Создать модель ИНС
# - Настроить параметры обучения
# - Обучить и оценить модель

# %% [markdown]
# ### Выполнение работы

# %% [markdown]
# Базовая архитектура: входной слой с 4 нейронами и функцией активации ReLU, выходный слой с 3 нейронами и активацией softmax для классификации трех классов.
# Обучение модели на данных X и dummy_y с 75 эпохами, размером пакета 10 и 10% данных для валидации.

# %%
import pandas
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

dataframe = pandas.read_csv("iris.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:4].astype(float)
Y = dataset[:,4]

encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
dummy_y = to_categorical(encoded_Y)
model = Sequential()
model.add(Dense(4, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X, dummy_y, epochs=75, batch_size=10, validation_split=0.1)

# Построение графика Accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
# Построение графика Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()
# Out:
# Epoch 1/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.2778 - loss: 1.2220 - val_accuracy: 1.0000 - val_loss: 0.8738
# Epoch 2/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2808 - loss: 1.1878 - val_accuracy: 1.0000 - val_loss: 0.9285
# Epoch 3/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2544 - loss: 1.1742 - val_accuracy: 1.0000 - val_loss: 0.9786
# Epoch 4/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2951 - loss: 1.1366 - val_accuracy: 1.0000 - val_loss: 1.0193
# Epoch 5/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2994 - loss: 1.1412 - val_accuracy: 0.7333 - val_loss: 1.0549
# Epoch 6/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1305 - loss: 1.1343 - val_accuracy: 0.0000e+00 - val_loss: 1.0869
# Epoch 7/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0399 - loss: 1.1176 - val_accuracy: 0.0000e+00 - val_loss: 1.1152
# Epoch 8/75
# ...

# %% [markdown]
# 2 входных слоя с 8 нейронами и функцией активации ReLU, выходный слой с 3 нейронами и активацией softmax для классификации трех классов.
# Обучение модели на данных X и dummy_y с 75 эпохами, размером пакета 10 и 10% данных для валидации.

# %%
import pandas
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

dataframe = pandas.read_csv("iris.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:4].astype(float)
Y = dataset[:,4]

encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
dummy_y = to_categorical(encoded_Y)
model = Sequential()
model.add(Dense(8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy',
metrics=['accuracy'])
history = model.fit(X, dummy_y, epochs=75, batch_size=10, validation_split=0.1)

# Построение графика Accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
# Построение графика Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()
# Out:
# Epoch 1/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 100ms/step - accuracy: 0.3718 - loss: 2.6306 - val_accuracy: 0.0000e+00 - val_loss: 4.2567
# Epoch 2/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4238 - loss: 1.7825 - val_accuracy: 0.0000e+00 - val_loss: 3.0019
# Epoch 3/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4253 - loss: 1.4211 - val_accuracy: 0.0000e+00 - val_loss: 2.1091
# Epoch 4/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3818 - loss: 1.2371 - val_accuracy: 0.0000e+00 - val_loss: 1.5543
# Epoch 5/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3945 - loss: 1.0434 - val_accuracy: 0.0000e+00 - val_loss: 1.2957
# Epoch 6/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3839 - loss: 0.9006 - val_accuracy: 0.0000e+00 - val_loss: 1.1958
# Epoch 7/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5987 - loss: 0.7797 - val_accuracy: 0.0000e+00 - val_loss: 1.0894
# Epoch 8/75
# ...

# %% [markdown]
# Входной слой с 8 нейронами и функцией активации ReLU, выходный слой с 3 нейронами и активацией softmax для классификации трех классов.
# Обучение модели на данных X и dummy_y с 75 эпохами, размером пакета 10 и 10% данных для валидации.

# %%
import pandas
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

dataframe = pandas.read_csv("iris.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:4].astype(float)
Y = dataset[:,4]

encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
dummy_y = to_categorical(encoded_Y)
model = Sequential()
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X, dummy_y, epochs=75, batch_size=10, validation_split=0.1)

# Построение графика Accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
# Построение графика Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()
# Out:
# Epoch 1/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.4012 - loss: 1.3332 - val_accuracy: 0.0000e+00 - val_loss: 2.8400
# Epoch 2/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3650 - loss: 1.3386 - val_accuracy: 0.0000e+00 - val_loss: 2.4687
# Epoch 3/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3627 - loss: 1.2482 - val_accuracy: 0.0000e+00 - val_loss: 2.1332
# Epoch 4/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3911 - loss: 1.0829 - val_accuracy: 0.0000e+00 - val_loss: 1.8555
# Epoch 5/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4030 - loss: 1.0537 - val_accuracy: 0.0000e+00 - val_loss: 1.6030
# Epoch 6/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4420 - loss: 0.9813 - val_accuracy: 0.0000e+00 - val_loss: 1.4245
# Epoch 7/75
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4349 - loss: 0.9912 - val_accuracy: 0.0000e+00 - val_loss: 1.2752
# Epoch 8/75
# ...

# %% [markdown]
# Входной слой с 8 нейронами и функцией активации ReLU, выходный слой с 3 нейронами и активацией softmax для классификации трех классов.
# Обучение модели на данных X и dummy_y с 75 эпохами, размером пакета 20 и 10% данных для валидации.

# %%
import pandas
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

dataframe = pandas.read_csv("iris.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:4].astype(float)
Y = dataset[:,4]

encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
dummy_y = to_categorical(encoded_Y)
model = Sequential()
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X, dummy_y, epochs=100, batch_size=20, validation_split=0.1)

# Построение графика Accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
# Построение графика Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.3362 - loss: 1.6752 - val_accuracy: 1.0000 - val_loss: 0.3338
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4695 - loss: 1.6553 - val_accuracy: 1.0000 - val_loss: 0.3428
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5358 - loss: 1.5159 - val_accuracy: 1.0000 - val_loss: 0.3557
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5083 - loss: 1.3408 - val_accuracy: 1.0000 - val_loss: 0.3703
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5458 - loss: 1.3780 - val_accuracy: 1.0000 - val_loss: 0.3836
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5093 - loss: 1.2562 - val_accuracy: 1.0000 - val_loss: 0.4026
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4173 - loss: 1.2251 - val_accuracy: 1.0000 - val_loss: 0.4300
# Epoch 8/100
# ...

# %% [markdown]
# Входной слой с 8 нейронами и функцией активации ReLU, выходный слой с 3 нейронами и активацией softmax для классификации трех классов.
# Обучение модели на данных X и dummy_y со 100 эпохами, размером пакета 10 и 1% данных для валидации.

# %%
import pandas
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

dataframe = pandas.read_csv("iris.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:4].astype(float)
Y = dataset[:,4]

encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
dummy_y = to_categorical(encoded_Y)
model = Sequential()
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X, dummy_y, epochs=100, batch_size=10, validation_split=0.01)

# Построение графика Accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
# Построение графика Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()
# Out:
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.3212 - loss: 4.1780 - val_accuracy: 0.0000e+00 - val_loss: 6.6571
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.3396 - loss: 3.2614 - val_accuracy: 0.0000e+00 - val_loss: 5.8381
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3126 - loss: 3.0525 - val_accuracy: 0.0000e+00 - val_loss: 5.1159
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2787 - loss: 2.7031 - val_accuracy: 0.0000e+00 - val_loss: 4.5396
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4221 - loss: 1.9502 - val_accuracy: 0.0000e+00 - val_loss: 4.0850
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2769 - loss: 2.2565 - val_accuracy: 0.0000e+00 - val_loss: 3.6755
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2799 - loss: 2.0400 - val_accuracy: 0.0000e+00 - val_loss: 3.3220
# Epoch 8/100
# ...

# %% [markdown]
# Входной слой с 8 нейронами и функцией активации ReLU, выходный слой с 3 нейронами и активацией softmax для классификации трех классов.
# Обучение модели на данных X и dummy_y со 100 эпохами, размером пакета 10 и 10% данных для валидации.

# %%
import pandas
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

dataframe = pandas.read_csv("iris.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:4].astype(float)
Y = dataset[:,4]

encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
dummy_y = to_categorical(encoded_Y)
model = Sequential()
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X, dummy_y, epochs=100, batch_size=10, validation_split=0.1)

# Построение графика Accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
# Построение графика Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()
# Out:
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.3873 - loss: 1.5429 - val_accuracy: 0.0000e+00 - val_loss: 2.1511
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.3886 - loss: 1.2286 - val_accuracy: 0.0000e+00 - val_loss: 1.9825
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.4438 - loss: 1.1250 - val_accuracy: 0.0000e+00 - val_loss: 1.8359
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6604 - loss: 1.0414 - val_accuracy: 0.0000e+00 - val_loss: 1.6937
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.6605 - loss: 1.0846 - val_accuracy: 0.0000e+00 - val_loss: 1.4663
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7647 - loss: 0.9281 - val_accuracy: 0.0000e+00 - val_loss: 1.4021
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7248 - loss: 0.9230 - val_accuracy: 0.0000e+00 - val_loss: 1.2626
# Epoch 8/100
# ...

# %% [markdown]
# Входной слой с 12 нейронами и функцией активации ReLU, выходный слой с 3 нейронами и активацией softmax для классификации трех классов.
# Обучение модели на данных X и dummy_y с 75 эпохами, размером пакета 10 и 10% данных для валидации.

# %%
import pandas
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

dataframe = pandas.read_csv("iris.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:4].astype(float)
Y = dataset[:,4]

encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
dummy_y = to_categorical(encoded_Y)
model = Sequential()
model.add(Dense(12, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(X, dummy_y, epochs=100, batch_size=10, validation_split=0.1)

# Построение графика Accuracy
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
# Построение графика Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.show()
# Out:
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.4014 - loss: 2.0798 - val_accuracy: 0.0000e+00 - val_loss: 2.2886
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4125 - loss: 1.5695 - val_accuracy: 0.0000e+00 - val_loss: 1.5740
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3831 - loss: 1.3559 - val_accuracy: 0.0000e+00 - val_loss: 1.0765
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4208 - loss: 1.0924 - val_accuracy: 0.6667 - val_loss: 0.7759
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5792 - loss: 0.9279 - val_accuracy: 1.0000 - val_loss: 0.6281
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6148 - loss: 0.8743 - val_accuracy: 1.0000 - val_loss: 0.5551
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5802 - loss: 0.8506 - val_accuracy: 1.0000 - val_loss: 0.5296
# Epoch 8/100
# ...

# %% [markdown]
# ### Вывод
# При изучении различных архитектур нейронных сетей и параметров обучения было подготовлено несколько моделей. Модель, состоящая из входного слоя с 8 нейронами и функцией активации ReLU, выходный слой с 3 нейронами и активацией softmax для классификации трех классов, обученная на 100 эпохах, размере пакета 10 и 10% данных для валидации оказалась наилучшей из полученных, так как точность на тренировочной и валидационной выборках стремилась к 1, а потери - к 0. При этом не было достигнуто переобучение модели.
